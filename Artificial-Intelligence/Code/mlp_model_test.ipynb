# %%
# %run mlp_model.ipynb
# %run dataset_chap123.ipynb
# %run dataset_flowers.ipynb

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.191, accuracy=0.733/0.711 (0/0 secs)
#     Epoch 4: cost=7.392, accuracy=0.744/0.694 (0/0 secs)
#     Epoch 6: cost=7.247, accuracy=0.747/0.737 (0/0 secs)
#     Epoch 8: cost=7.139, accuracy=0.748/0.725 (0/0 secs)
#     Epoch 10: cost=7.054, accuracy=0.751/0.746 (0/0 secs)
# Model abalone_model train ended in 0 secs:
# Model abalone_model test report: accuracy = 0.727, (0 secs)
#
# Model abalone_model Visualization
# [0.00,0.00,1.00,0.70,0.53,0.17,1.56,0.61,0.39,0.44] => 추정 12.9 : 정답 10.0
# [0.00,1.00,0.00,0.46,0.38,0.12,0.48,0.22,0.10,0.17] => 추정  8.7 : 정답  7.0
# [0.00,0.00,1.00,0.58,0.45,0.14,1.14,0.56,0.22,0.29] => 추정 11.3 : 정답  8.0

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad ,[5,3])
am.exec_all(epoch_count=1000, report=200,\
            batch_size=100, learning_rate=0.003,\
            show_cnt=5)
# Out:
# Model abalone_model train started:
#     Epoch 200: cost=10.403, accuracy=0.678/0.661 (3/3 secs)
#     Epoch 400: cost=10.403, accuracy=0.677/0.702 (1/4 secs)
#     Epoch 600: cost=10.403, accuracy=0.678/0.717 (3/7 secs)
#     Epoch 800: cost=10.403, accuracy=0.677/0.694 (1/8 secs)
#     Epoch 1000: cost=10.403, accuracy=0.677/0.661 (2/10 secs)
# Model abalone_model train ended in 10 secs:
# Model abalone_model test report: accuracy = 0.678, (0 secs)
#
# Model abalone_model Visualization
# [1.00,0.00,0.00,0.34,0.26,0.09,0.18,0.07,0.04,0.06] => 추정  9.9 : 정답  9.0
# [1.00,0.00,0.00,0.48,0.38,0.12,0.62,0.34,0.11,0.17] => 추정  9.9 : 정답  8.0
# [1.00,0.00,0.00,0.11,0.09,0.03,0.01,0.00,0.00,0.00] => 추정  9.9 : 정답  3.0
# [1.00,0.00,0.00,0.35,0.27,0.10,0.22,0.08,0.04,0.07] => 추정  9.9 : 정답 10.0
# [0.00,1.00,0.00,0.35,0.27,0.11,0.30,0.14,0.06,0.09] => 추정  9.9 : 정답  7.0

# %%
print(am)
am.visualize(5)
# Out:
# abalone_model/abalone(regression, 3340+629+208)

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [5])
pm.exec_all(show_)
# Out:
# Model pulsar_model train ended in 3 secs:
# Model pulsar_model test report: accuracy = 0.969, (0 secs)
#
# Model pulsar_model Visualization
# [108.5, 51.4,  0.2,...] => 추정 별(확률 0.01) : 정답 별 => O
# [108.9, 50.1,  0.3,...] => 추정 별(확률 0.02) : 정답 별 => O
# [111.4, 44.4,  0.2,...] => 추정 별(확률 0.01) : 정답 별 => O

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [10,5])
pm.exec_all(epoch_count=100,report=10,show_cnt=4)
pm.visualize(5)
# Out:
# Model pulsar_model train started:
#     Epoch 10: cost=0.094, accuracy=0.970/0.970 (9/9 secs)
#     Epoch 20: cost=0.089, accuracy=0.974/0.990 (10/19 secs)
#     Epoch 30: cost=0.087, accuracy=0.975/0.970 (14/33 secs)
#     Epoch 40: cost=0.086, accuracy=0.974/0.960 (9/42 secs)
#     Epoch 50: cost=0.085, accuracy=0.975/0.950 (5/47 secs)
#     Epoch 60: cost=0.084, accuracy=0.976/0.990 (4/51 secs)
#     Epoch 70: cost=0.083, accuracy=0.975/0.980 (5/56 secs)
#     Epoch 80: cost=0.083, accuracy=0.977/1.000 (6/62 secs)
#     Epoch 90: cost=0.082, accuracy=0.976/1.000 (6/68 secs)
#     Epoch 100: cost=0.082, accuracy=0.976/0.990 (4/72 secs)
# Model pulsar_model train ended in 72 secs:
# Model pulsar_model test report: accuracy = 0.969, (0 secs)
#
# Model pulsar_model Visualization
# [ 96.5, 35.7,  0.4,...] => 추정 별(확률 0.01) : 정답 별 => O
# [121.4, 47.6,  0.1,...] => 추정 별(확률 0.00) : 정답 별 => O
# [116.8, 44.4,  0.1,...] => 추정 별(확률 0.01) : 정답 별 => O
# [108.7, 52.6,  0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# Model pulsar_model Visualization
# [108.0, 46.4,  0.3,...] => 추정 별(확률 0.00) : 정답 별 => O
# [116.6, 51.7,  0.4,...] => 추정 별(확률 0.00) : 정답 별 => O
# [112.4, 52.3,  0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# [ 39.4, 34.8,  4.2,...] => 추정 펄서(확률 0.99) : 정답 펄서 => O
# [138.7, 51.7, -0.1,...] => 추정 별(확률 0.00) : 정답 별 => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.854, accuracy=0.341/0.381 (0/0 secs)
#     Epoch 20: cost=1.793, accuracy=0.341/0.381 (1/1 secs)
#     Epoch 30: cost=1.756, accuracy=0.341/0.381 (0/1 secs)
#     Epoch 40: cost=1.732, accuracy=0.341/0.381 (1/2 secs)
#     Epoch 50: cost=1.717, accuracy=0.341/0.381 (0/2 secs)
# Model steel_model train ended in 2 secs:
# Model steel_model test report: accuracy = 0.367, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [10,11,17, 8, 7,18,29] => 추정 Other_Faults : 정답 Pastry => X
# 추정확률분포 [10,11,17, 8, 7,18,29] => 추정 Other_Faults : 정답 Pastry => X
# 추정확률분포 [10,11,17, 8, 7,18,29] => 추정 Other_Faults : 정답 Other_Faults => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7,5])
sm.exec_all(epoch_count=100, report=20,learning_rate= 0.003)
# Out:
# Model steel_model train started:
#     Epoch 20: cost=1.696, accuracy=0.335/0.402 (1/1 secs)
#     Epoch 40: cost=1.672, accuracy=0.335/0.402 (2/3 secs)
#     Epoch 60: cost=1.667, accuracy=0.335/0.402 (2/5 secs)
#     Epoch 80: cost=1.666, accuracy=0.335/0.402 (1/6 secs)
#     Epoch 100: cost=1.665, accuracy=0.335/0.402 (2/8 secs)
# Model steel_model train ended in 8 secs:
# Model steel_model test report: accuracy = 0.391, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 8,10,21, 4, 3,22,33] => 추정 Other_Faults : 정답 Other_Faults => O
# 추정확률분포 [ 8,10,21, 4, 3,22,33] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 8,10,21, 4, 3,22,33] => 추정 Other_Faults : 정답 Other_Faults => O

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [12,7,5])
psm.exec_all(epoch_count=100, report=20,learning_rate= 0.003)
# Out:
# Model pulsar_select_model train started:
#     Epoch 20: cost=0.094, accuracy=0.974/0.990 (11/11 secs)
#     Epoch 40: cost=0.088, accuracy=0.973/0.990 (14/25 secs)
#     Epoch 60: cost=0.086, accuracy=0.974/0.980 (18/43 secs)
#     Epoch 80: cost=0.085, accuracy=0.974/0.970 (16/59 secs)
#     Epoch 100: cost=0.084, accuracy=0.975/0.980 (12/71 secs)
# Model pulsar_select_model train ended in 71 secs:
# Model pulsar_select_model test report: accuracy = 0.972, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [99, 1] => 추정 별 : 정답 별 => O

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [30,15,10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.415, accuracy=0.364/0.360 (13/13 secs)
#     Epoch 4: cost=1.300, accuracy=0.410/0.370 (14/27 secs)
#     Epoch 6: cost=1.248, accuracy=0.446/0.490 (15/42 secs)
#     Epoch 8: cost=1.204, accuracy=0.459/0.450 (18/60 secs)
#     Epoch 10: cost=1.173, accuracy=0.484/0.350 (15/75 secs)
# Model flowers_model_1 train ended in 75 secs:
# Model flowers_model_1 test report: accuracy = 0.438, (1 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [ 4, 9, 5,68,13] => 추정 sunflower : 정답 dandelion => X
# 추정확률분포 [ 6,67, 1,17, 9] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [26,28,15,11,19] => 추정 dandelion : 정답 sunflower => X

# %%
fm.visualize(5)
# Out:
# Model flowers_model_1 Visualization
# 추정확률분포 [ 1, 1,22, 6,71] => 추정 tulip : 정답 rose => X
# 추정확률분포 [14,26,24, 6,30] => 추정 tulip : 정답 rose => X
# 추정확률분포 [20,34,19, 2,25] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [10,16, 8,50,16] => 추정 sunflower : 정답 sunflower => O
# 추정확률분포 [41,49, 5, 0, 4] => 추정 dandelion : 정답 daisy => X

# %%
fm2 = MlpModel('flowers_model_2', fd, [45,30,15,5])
fm2.exec_all(epoch_count=100, report=10)

# %%
fm2.visualize(5)
