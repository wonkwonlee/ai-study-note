# %%
# %run cnn_basic_model.ipynb
# %run dataset_flowers.ipynb
# %run dataset_office31.ipynb

# %%
fd = FlowersDataset([96, 96], [96, 96, 3])
od = Office31Dataset([96, 96], [96, 96, 3])

# %%
fm1 = CnnBasicModel('flowers_model_1', fd, [30, 10])
fm1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.568, accuracy=0.311/0.360 (23/23 secs)
#     Epoch 4: cost=1.424, accuracy=0.372/0.380 (19/42 secs)
#     Epoch 6: cost=1.357, accuracy=0.419/0.380 (22/64 secs)
#     Epoch 8: cost=1.314, accuracy=0.431/0.330 (20/84 secs)
#     Epoch 10: cost=1.298, accuracy=0.424/0.410 (19/103 secs)
# Model flowers_model_1 train ended in 103 secs:
# Model flowers_model_1 test report: accuracy = 0.419, (1 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [32,42, 0, 9, 7, 9] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 9,25, 0,10,37,19] => 추정 sunflower : 정답 rose => X
# 추정확률분포 [16,15, 0,30, 8,30] => 추정 tulip : 정답 tulip => O

# %%
fm2 = CnnBasicModel('flowers_model_2', fd, 
                    [['full', {'width':30}], 
                     ['full', {'width':10}]])
fm2.use_adam = False
fm2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.459, accuracy=0.350/0.250 (4/4 secs)
#     Epoch 4: cost=1.357, accuracy=0.403/0.410 (5/9 secs)
#     Epoch 6: cost=1.313, accuracy=0.426/0.430 (5/14 secs)
#     Epoch 8: cost=1.277, accuracy=0.439/0.390 (6/20 secs)
#     Epoch 10: cost=1.231, accuracy=0.463/0.450 (4/24 secs)
# Model flowers_model_2 train ended in 24 secs:
# Model flowers_model_2 test report: accuracy = 0.364, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [29,63, 0, 2, 1, 6] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [30,26, 0,13,11,20] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [ 0, 0, 0,85, 0,15] => 추정 rose : 정답 rose => O

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['avg', {'stride':2}]], 
               True)
fm3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_3 train started:
#     Epoch 2: cost=1.129, accuracy=0.546/0.540 (220/220 secs)
#     Epoch 4: cost=0.899, accuracy=0.664/0.530 (241/461 secs)
#     Epoch 6: cost=0.761, accuracy=0.714/0.660 (269/730 secs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d56e4cafd00b> in <module>
#       5                 ['avg', {'stride':2}]],
#       6                True)
# ----> 7 fm3.exec_all(epoch_count = 10, report = 2)
#       8
#
# <ipython-input-1-b56138f72c2c> in exec_all(self, epoch_count, batch_size, learning_rate, report, show_cnt)
#      11     def exec_all(self, epoch_count=10, batch_size=10, learning_rate=0.001,
#      12                  report=0, show_cnt=3):
# ---> 13         self.train(epoch_count, batch_size, learning_rate, report)
#      14         self.test()
#      15         if show_cnt > 0: self.visualize(show_cnt)
#
# <ipython-input-1-7af4e6cb7d16> in mlp_model_train(self, epoch_count, batch_size, learning_rate, report)
#      13         for n in range(batch_count):
#      14             trX, trY = self.dataset.get_train_data(batch_size, n)
# ---> 15             cost, acc = self.train_step(trX, trY)
#      16             costs.append(cost)
#      17             accs.append(acc)
#
# <ipython-input-1-b56f9a4a51fa> in mlp_train_step(self, x, y)
#       7     G_loss = 1.0
#       8     G_output = self.backprop_postproc(G_loss, aux_pp)
# ----> 9     self.backprop_neuralnet(G_output, aux_nn)
#      10
#      11     return loss, accuracy
#
# <ipython-input-1-242a7e666546> in mlp_backprop_neuralnet(self, G_output, aux)
#      23     for n in reversed(range(len(self.hconfigs))):
#      24         hconfig, pm, aux = self.hconfigs[n], self.pm_hiddens[n], aux_layers[n]
# ---> 25         G_hidden = self.backprop_layer(G_hidden, hconfig, pm, aux)
#      26
#      27     return G_hidden
#
# <ipython-input-1-df1e7eadfabb> in cnn_basic_backprop_layer(self, G_y, hconfig, pm, aux)
#       4     m_name = 'backprop_{}_layer'.format(layer_type)
#       5     method = getattr(self, m_name)
# ----> 6     G_input = method(G_y, hconfig, pm, aux)
#       7
#       8     return G_input
#
# KeyboardInterrupt:

# %%
fm4 = CnnBasicModel('flowers_model_4', fd, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
fm4.exec_all(epoch_count = 10, report = 2)

# %%
om1 = CnnBasicModel('office31_model_1', od, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
om1.exec_all(epoch_count = 10, report = 2)

# %%
om1.exec_all(epoch_count = 40, show_cnt = 0)

# %%
om2 = CnnBasicModel('office31_model_2', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'sigmoid'}], 
                ['avg', {'stride':3}]])
om2.exec_all(epoch_count = 10, report = 2)

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'tanh'}], 
                ['avg', {'stride':3}]])
om3.exec_all(epoch_count = 10, report = 2)
