# %%
# %run adam_model.ipynb
# %run dataset_office31.ipynb

# %%
od = Office31Dataset()

# %%
om1 = AdamModel('office31_model_1', od, [10])
om1.exec_all(epoch_count=20, report=10)
# Out:
# Model office31_model_1 train started:
#     Epoch 10: cost=4.296, accuracy=0.685+0.035/0.790+0.040 (36/36 secs)
#     Epoch 20: cost=4.268, accuracy=0.685+0.037/0.780+0.020 (35/71 secs)
# Model office31_model_1 train ended in 71 secs:
# Model office31_model_1 test report: accuracy = 0.661+0.048, (0 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 dslr => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 ring_binder => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 pen => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 mouse => X

# %%
om1.visualize(3)
# Out:
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 desk_chair => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 mug => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 paper_notebook => X

# %%
om2 = AdamModel('office31_model_2', od, [64,32,10])
om2.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_2 train started:
#     Epoch 10: cost=3.682, accuracy=0.791+0.097/0.850+0.030 (95/95 secs)
#     Epoch 20: cost=3.440, accuracy=0.830+0.135/0.900+0.050 (97/192 secs)
#     Epoch 30: cost=3.299, accuracy=0.844+0.153/0.820+0.150 (97/289 secs)
#     Epoch 40: cost=3.194, accuracy=0.856+0.167/0.860+0.080 (99/388 secs)
#     Epoch 50: cost=3.110, accuracy=0.861+0.192/0.850+0.110 (96/484 secs)
# Model office31_model_2 train ended in 484 secs:
# Model office31_model_2 test report: accuracy = 0.840+0.176, (0 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [97, 0, 2] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 1, 0, 1, 7, 0, 8, 3, 1,...] => 추정 headphones : 정답 tape_dispenser => X
# 추정확률분포 [ 0, 0, 4, 1, 0, 2, 0, 0,...] => 추정 stapler : 정답 letter_tray => X
# 추정확률분포 [ 0, 6, 0, 1, 3, 1, 1,10,...] => 추정 pen : 정답 ruler => X

# %%
om3 = AdamModel('office31_model_3', od, [64,32,10])
om2.use_adam = True
om3.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_3 train started:
#     Epoch 10: cost=3.711, accuracy=0.819+0.084/0.860+0.060 (97/97 secs)
#     Epoch 20: cost=3.311, accuracy=0.869+0.163/0.860+0.150 (95/192 secs)
#     Epoch 30: cost=3.103, accuracy=0.883+0.204/0.870+0.160 (93/285 secs)
#     Epoch 40: cost=2.935, accuracy=0.894+0.241/0.860+0.230 (92/377 secs)
#     Epoch 50: cost=2.799, accuracy=0.904+0.264/0.850+0.180 (96/473 secs)
# Model office31_model_3 train ended in 473 secs:
# Model office31_model_3 test report: accuracy = 0.890+0.234, (0 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [99, 1, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 1, 1, 2, 5, 2, 1,12,...] => 추정 desk_lamp : 정답 scissors => X
# 추정확률분포 [ 3, 1, 1,10, 6, 2, 0,11,...] => 추정 paper_notebook : 정답 printer => X
# 추정확률분포 [ 0, 0, 2, 2, 0, 1, 2, 1,...] => 추정 stapler : 정답 calculator => X
