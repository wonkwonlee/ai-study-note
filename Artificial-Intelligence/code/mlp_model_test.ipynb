# %%
# %run mlp_model.ipynb
# %run dataset_chap123.ipynb
# %run dataset_flowers.ipynb

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.150, accuracy=0.735/0.709 (0/0 secs)
#     Epoch 4: cost=7.366, accuracy=0.744/0.721 (1/1 secs)
#     Epoch 6: cost=7.230, accuracy=0.746/0.717 (0/1 secs)
#     Epoch 8: cost=7.127, accuracy=0.750/0.755 (0/1 secs)
#     Epoch 10: cost=7.048, accuracy=0.751/0.725 (0/1 secs)
# Model abalone_model train ended in 1 secs:
# Model abalone_model test report: accuracy = 0.728, (0 secs)
#
# Model abalone_model Visualization
# [0.00,1.00,0.00,0.56,0.47,0.17,0.99,0.39,0.18,0.37] => 추정 10.7 : 정답 15.0
# [0.00,0.00,1.00,0.61,0.47,0.17,1.30,0.51,0.34,0.32] => 추정 11.9 : 정답 14.0
# [0.00,1.00,0.00,0.39,0.30,0.12,0.34,0.16,0.09,0.10] => 추정  8.0 : 정답  6.0

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad ,[5,3])
am.exec_all(epoch_count=1000, report=200,\
            batch_size=100, learning_rate=0.003,\
            show_cnt=5)
# Out:
# Model abalone_model train started:
#     Epoch 200: cost=10.403, accuracy=0.678/0.661 (2/2 secs)
#     Epoch 400: cost=10.403, accuracy=0.677/0.702 (2/4 secs)
#     Epoch 600: cost=10.403, accuracy=0.678/0.717 (2/6 secs)
#     Epoch 800: cost=10.403, accuracy=0.677/0.694 (2/8 secs)
#     Epoch 1000: cost=10.403, accuracy=0.677/0.661 (1/9 secs)
# Model abalone_model train ended in 9 secs:
# Model abalone_model test report: accuracy = 0.678, (0 secs)
#
# Model abalone_model Visualization
# [1.00,0.00,0.00,0.34,0.26,0.09,0.18,0.07,0.04,0.06] => 추정  9.9 : 정답  9.0
# [1.00,0.00,0.00,0.48,0.38,0.12,0.62,0.34,0.11,0.17] => 추정  9.9 : 정답  8.0
# [1.00,0.00,0.00,0.11,0.09,0.03,0.01,0.00,0.00,0.00] => 추정  9.9 : 정답  3.0
# [1.00,0.00,0.00,0.35,0.27,0.10,0.22,0.08,0.04,0.07] => 추정  9.9 : 정답 10.0
# [0.00,1.00,0.00,0.35,0.27,0.11,0.30,0.14,0.06,0.09] => 추정  9.9 : 정답  7.0

# %%
print(am)
am.visualize(5)
# Out:
# abalone_model/abalone(regression, 3340+629+208)
# Model abalone_model Visualization
# [0.00,1.00,0.00,0.59,0.48,0.18,1.18,0.53,0.30,0.31] => 추정  9.9 : 정답 10.0
# [0.00,1.00,0.00,0.45,0.34,0.14,0.48,0.21,0.10,0.11] => 추정  9.9 : 정답 15.0
# [0.00,0.00,1.00,0.72,0.56,0.17,1.61,0.72,0.33,0.49] => 추정  9.9 : 정답 12.0
# [0.00,0.00,1.00,0.66,0.54,0.17,1.52,0.71,0.31,0.41] => 추정  9.9 : 정답 12.0
# [1.00,0.00,0.00,0.35,0.27,0.10,0.22,0.08,0.04,0.07] => 추정  9.9 : 정답 10.0

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [5])
pm.exec_all()
# Out:
# Model pulsar_model train ended in 3 secs:
# Model pulsar_model test report: accuracy = 0.972, (0 secs)
#
# Model pulsar_model Visualization
# [103.4, 40.6,  0.5,...] => 추정 별(확률 0.01) : 정답 별 => O
# [136.7, 48.8, -0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# [122.5, 43.6,  0.3,...] => 추정 별(확률 0.00) : 정답 별 => O

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [10,5])
pm.exec_all(epoch_count=100,report=10,show_cnt=4)
pm.visualize(5)
# Out:
# Model pulsar_model train started:
#     Epoch 10: cost=0.096, accuracy=0.971/0.970 (4/4 secs)
#     Epoch 20: cost=0.090, accuracy=0.974/0.960 (4/8 secs)
#     Epoch 30: cost=0.087, accuracy=0.974/0.940 (4/12 secs)
#     Epoch 40: cost=0.087, accuracy=0.974/0.970 (4/16 secs)
#     Epoch 50: cost=0.086, accuracy=0.975/0.930 (4/20 secs)
#     Epoch 60: cost=0.085, accuracy=0.975/0.990 (4/24 secs)
#     Epoch 70: cost=0.086, accuracy=0.975/0.920 (5/29 secs)
#     Epoch 80: cost=0.085, accuracy=0.974/0.970 (3/32 secs)
#     Epoch 90: cost=0.084, accuracy=0.975/0.990 (4/36 secs)
#     Epoch 100: cost=0.084, accuracy=0.975/0.980 (4/40 secs)
# Model pulsar_model train ended in 40 secs:
# Model pulsar_model test report: accuracy = 0.977, (0 secs)
#
# Model pulsar_model Visualization
# [104.6, 35.0,  0.3,...] => 추정 별(확률 0.03) : 정답 별 => O
# [ 52.4, 40.2,  2.2,...] => 추정 펄서(확률 0.98) : 정답 별 => X
# [105.6, 44.3,  0.5,...] => 추정 별(확률 0.00) : 정답 별 => O
# [ 86.5, 34.7,  0.9,...] => 추정 별(확률 0.02) : 정답 별 => O
# Model pulsar_model Visualization
# [ 75.3, 39.3,  0.7,...] => 추정 별(확률 0.10) : 정답 별 => O
# [141.6, 48.5, -0.0,...] => 추정 별(확률 0.00) : 정답 별 => O
# [131.0, 51.3,  0.1,...] => 추정 별(확률 0.00) : 정답 별 => O
# [131.7, 50.3, -0.1,...] => 추정 별(확률 0.01) : 정답 별 => O
# [109.1, 40.5,  0.1,...] => 추정 별(확률 0.00) : 정답 별 => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.845, accuracy=0.358/0.320 (1/1 secs)
#     Epoch 20: cost=1.779, accuracy=0.358/0.320 (0/1 secs)
#     Epoch 30: cost=1.739, accuracy=0.358/0.320 (1/2 secs)
#     Epoch 40: cost=1.715, accuracy=0.358/0.320 (0/2 secs)
#     Epoch 50: cost=1.700, accuracy=0.358/0.320 (1/3 secs)
# Model steel_model train ended in 3 secs:
# Model steel_model test report: accuracy = 0.296, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 9,10,17, 8, 7,18,31] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 9,10,17, 8, 7,18,31] => 추정 Other_Faults : 정답 K_Scatch => X
# 추정확률분포 [ 9,10,17, 8, 7,18,31] => 추정 Other_Faults : 정답 Bumps => X

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7,5])
sm.exec_all(epoch_count=100, report=20,learning_rate= 0.003)
# Out:
# Model steel_model train started:
#     Epoch 20: cost=1.696, accuracy=0.355/0.381 (1/1 secs)
#     Epoch 40: cost=1.674, accuracy=0.355/0.381 (1/2 secs)
#     Epoch 60: cost=1.669, accuracy=0.355/0.381 (1/3 secs)
#     Epoch 80: cost=1.667, accuracy=0.355/0.381 (1/4 secs)
#     Epoch 100: cost=1.666, accuracy=0.355/0.381 (1/5 secs)
# Model steel_model train ended in 5 secs:
# Model steel_model test report: accuracy = 0.303, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 8,10,19, 4, 3,20,35] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 8,10,19, 4, 3,20,35] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 8,10,19, 4, 3,20,35] => 추정 Other_Faults : 정답 Bumps => X

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [12,7,5])
psm.exec_all(epoch_count=100, report=20,learning_rate= 0.003)
# Out:
# Model pulsar_select_model train started:
#     Epoch 20: cost=0.097, accuracy=0.973/0.970 (9/9 secs)
#     Epoch 40: cost=0.093, accuracy=0.974/0.970 (9/18 secs)
#     Epoch 60: cost=0.091, accuracy=0.974/0.990 (9/27 secs)
#     Epoch 80: cost=0.091, accuracy=0.975/0.960 (8/35 secs)
#     Epoch 100: cost=0.090, accuracy=0.976/1.000 (9/44 secs)
# Model pulsar_select_model train ended in 44 secs:
# Model pulsar_select_model test report: accuracy = 0.973, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [96, 4] => 추정 별 : 정답 별 => O
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [99, 1] => 추정 별 : 정답 별 => O

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [30,15,10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.424, accuracy=0.372/0.410 (7/7 secs)
#     Epoch 4: cost=1.314, accuracy=0.403/0.370 (5/12 secs)
#     Epoch 6: cost=1.261, accuracy=0.429/0.410 (4/16 secs)
#     Epoch 8: cost=1.220, accuracy=0.457/0.450 (5/21 secs)
#     Epoch 10: cost=1.191, accuracy=0.467/0.370 (5/26 secs)
# Model flowers_model_1 train ended in 26 secs:
# Model flowers_model_1 test report: accuracy = 0.435, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [ 7, 5, 1,38, 5,44] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [31,31, 0,20, 1,17] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [14,14, 2, 8,34,28] => 추정 sunflower : 정답 daisy => X

# %%
fm.visualize(5)
# Out:
# Model flowers_model_1 Visualization
# 추정확률분포 [ 7,22, 0, 3,51,17] => 추정 sunflower : 정답 sunflower => O
# 추정확률분포 [20,42, 0, 9,13,16] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [13,21, 1, 8,36,22] => 추정 sunflower : 정답 daisy => X
# 추정확률분포 [ 1, 7, 0, 1,84, 8] => 추정 sunflower : 정답 sunflower => O
# 추정확률분포 [ 3, 7, 0, 7,42,42] => 추정 tulip : 정답 tulip => O

# %%
fm2 = MlpModel('flowers_model_2', fd, [45,30,15,5])
fm2.exec_all(epoch_count=100, report=10)
# Out:
# Model flowers_model_2 train started:
#     Epoch 10: cost=1.253, accuracy=0.434/0.380 (35/35 secs)
#     Epoch 20: cost=1.078, accuracy=0.514/0.490 (34/69 secs)
#     Epoch 30: cost=0.895, accuracy=0.610/0.440 (62/131 secs)
#     Epoch 40: cost=0.687, accuracy=0.716/0.440 (57/188 secs)
#     Epoch 50: cost=0.573, accuracy=0.774/0.350 (47/235 secs)
#     Epoch 60: cost=0.474, accuracy=0.835/0.380 (51/286 secs)
#     Epoch 70: cost=0.311, accuracy=0.882/0.460 (45/331 secs)
#     Epoch 80: cost=0.358, accuracy=0.877/0.400 (53/384 secs)
#     Epoch 90: cost=0.159, accuracy=0.946/0.490 (49/433 secs)
#     Epoch 100: cost=0.362, accuracy=0.892/0.440 (58/491 secs)
# Model flowers_model_2 train ended in 491 secs:
# Model flowers_model_2 test report: accuracy = 0.469, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [ 1, 0, 0,97, 0, 1] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 0, 0, 0,92, 0, 8] => 추정 rose : 정답 rose => O
# 추정확률분포 [ 5,94, 0, 1, 1, 0] => 추정 dandelion : 정답 dandelion => O

# %%
fm2.visualize(5)
# Out:
# Model flowers_model_2 Visualization
# 추정확률분포 [ 5, 8, 0, 0,63,24] => 추정 sunflower : 정답 dandelion => X
# 추정확률분포 [ 0,100, 0, 0, 0, 0] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [ 2,97, 0, 0, 1, 0] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 0, 6, 0, 0,91, 3] => 추정 sunflower : 정답 dandelion => X
# 추정확률분포 [ 0, 1, 0, 0,97, 2] => 추정 sunflower : 정답 sunflower => O
